# %%
import pandas as pd

# %%
toronto_profile_csvpath = "Resources/neighbourhood-profiles-2016-csv.csv"

toronto_2016_raw_df = pd.read_csv(toronto_profile_csvpath)
toronto_2016_raw_df.head(20)
# Out:
#     _id                   Category                      Topic  \
# 0     1  Neighbourhood Information  Neighbourhood Information
# 1     2  Neighbourhood Information  Neighbourhood Information
# 2     3                 Population   Population and dwellings
# 3     4                 Population   Population and dwellings
# 4     5                 Population   Population and dwellings
# 5     6                 Population   Population and dwellings
# 6     7                 Population   Population and dwellings
# 7     8                 Population   Population and dwellings
# 8     9                 Population   Population and dwellings
# 9    10                 Population        Age characteristics
# 10   11                 Population        Age characteristics
# 11   12                 Population        Age characteristics
# 12   13                 Population        Age characteristics
# 13   14                 Population        Age characteristics
# ...

# %%
drop_rows_toronto_2016 = toronto_2016_raw_df.iloc[0:3,:]
drop_columns_toronto_2016 = drop_rows_toronto_2016.drop(columns=['_id','Category','Topic','Data Source','Characteristic','City of Toronto'])

# %%
drop_columns_toronto_2016
# Out:
#   Agincourt North Agincourt South-Malvern West       Alderwood  \
# 0             129                          128              20
# 1  No Designation               No Designation  No Designation
# 2          29,113                       23,757          12,054
#
#             Annex Banbury-Don Mills  Bathurst Manor Bay Street Corridor  \
# 0              95                42              34                  76
# 1  No Designation    No Designation  No Designation      No Designation
# 2          30,526            27,695          15,873              25,797
#
#   Bayview Village Bayview Woods-Steeles Bedford Park-Nortown  ...  \
# 0              52                    49                   39  ...
# 1  No Designation        No Designation       No Designation  ...
# 2          21,396                13,154               23,236  ...
#
#   Willowdale West Willowridge-Martingrove-Richview  Woburn Woodbine Corridor  \
# ...

# %%
toronto_2016_raw = drop_columns_toronto_2016.T

# %%
toronto_2016_raw.head()
# Out:
#                                 0               1       2
# Agincourt North               129  No Designation  29,113
# Agincourt South-Malvern West  128  No Designation  23,757
# Alderwood                      20  No Designation  12,054
# Annex                          95  No Designation  30,526
# Banbury-Don Mills              42  No Designation  27,695

# %%
toronto_2016_raw = toronto_2016_raw.drop(columns=[1])

# %%
toronto_2016 = toronto_2016_raw.reset_index()

# %%
toronto_2016.columns = ['Neighbourhood','Neighbourhood ID','Population'] 
toronto_2016
# Out:
#                     Neighbourhood Neighbourhood ID Population
# 0                 Agincourt North              129     29,113
# 1    Agincourt South-Malvern West              128     23,757
# 2                       Alderwood               20     12,054
# 3                           Annex               95     30,526
# 4               Banbury-Don Mills               42     27,695
# ..                            ...              ...        ...
# 135                      Wychwood               94     14,349
# 136                Yonge-Eglinton              100     11,817
# 137                Yonge-St.Clair               97     12,528
# 138       York University Heights               27     27,593
# 139            Yorkdale-Glen Park               31     14,804
#
# [140 rows x 3 columns]

# %%
toronto_neighbourhood_id_population = toronto_2016.set_index('Neighbourhood ID')

# %%
toronto_neighbourhood_id_population.head()
# Out:
#                                  Neighbourhood Population
# Neighbourhood ID
# 129                            Agincourt North     29,113
# 128               Agincourt South-Malvern West     23,757
# 20                                   Alderwood     12,054
# 95                                       Annex     30,526
# 42                           Banbury-Don Mills     27,695
